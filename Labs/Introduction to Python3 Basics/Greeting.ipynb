# %% [markdown]
#  # 🎯 pAIthon Labs: Master Python3 with Hands-On Fun! 🧪💻
#
# ![pAIthon Labs Logo](https://raw.githubusercontent.com/worldfamous718/pAIthon-Labs/main/Labs/Logos-Files/Lab-Logo.png)

# %% [markdown]
# <h1>Greeting Groups of People with Python3</h1>
#
# <h3>A World..redacted 3torial</h3>
#
#
# <h3>Problem Statement</h3>
# <p>Imagine you're organizing a social event for a group of friends. You have two lists: one containing the names of the boys attending and another containing the names of the girls. Your task is to write a Python3 program that greets each boy and his corresponding girl, if available, in a specific format.</p>
#
# <h3>Desired Outcome</h3>
# <p><span><code>boys = ['Bob', 'Phil', 'Jack', 'Peter']</code/></span></p>
# <pre><code>girls = ['Janet', 'Theresa', 'Jeannette', 'Lara']</pre></code>
# <pre><code>Hello Bob, and Janet</pre></code>
# <pre><code>Hello Phil, and Theresa</pre></code>
# <pre><code>Hello Jack, and Jeannette</pre></code>
# <pre><code>Hello Peter, and Lara</pre></code>
#
# <h3>Learning Objectives</h3>
# <p>By the end of this 3torial, you should be able to:</p>
# <ul>
#     <li>Understand how to work with multiple lists in Python3</li>
#     <li>Implement efficient looping structures</li>
#     <li>Use the<span><code>zip()</code></span>function to iterate over multiple lists simultaneously</li>
#     <li>Handle cases where lists might have different lengths</li>
#     <li>Write clean and readable Python code</li>
# </ul>
#
# <h3>1. Introduction to Lists in Python3</h3>
# <p>Lists are one of the most fundamental data structures in Python. They allow you to store collections of items in a single variable. Think of a list like a shopping cart – you can add multiple items to it, remove items, and rearrange them easily.</p>
#
# <h3>Key Points About Lists:</h3>
# <ul>
#     <li>Lists are denoted by square brackets [ ]</li>
#     <li>Items in a list are separated by commas</li>
#     <li>Lists can contain any type of object, including numbers, strings, other lists etc.</li>
# </ul>
# <h3>Basic Syntax:</h3>
# <span><code>my_list = [item1, item2, item3]</code></span>
#
# <h3>Common Operations:</h3>
# <ul>
#     <li>Accessing elements:
#      <span><code>my_list[0]</code></span></li>
#     <li>Adding elements:
#     <span><code>my_list.append(new_item)</code></span></li>
#     <li>Removing elements:
#     <span><code>my_list.remove(item_to_remove)</code></span></li>
#     <li>Getting the number of elements:
#     <span><code>len(my_list)</code></span></li>
# </ul>
#
#
# <h3>Creating Our Lists</h3>
# <p>Remember that lists are denoted by square brackets.</p>
# <pre><code>boys = []</pre></code>
# <pre><code>girls = []</pre></code>
#
# <p>Now we have an empty list for boys as well as one for girls. Empty brackets denote empty list.</p>
# <p>Allow us to add people to our list</p>
#
# <h3>Direct Assignment:</h3>
#
# <pre><code>boys = []</pre></code>
# <pre><code>boys = boys + ['Bob', 'Phil', 'Jack', 'Peter']</pre></code>
#
# <h3>Using append():</h3>
# <pre><code>girls = []</code></pre>
# <pre><code>girls.append('Janet')</code></pre>
# <pre><code>girls.append('Theresa')</code></pre>
# <pre><code>girls.append('Jeannette')</code></pre>
# <pre><code>girls.append('Lara')</pre></code>
#
# <p>Now enter the following command onto the console</p>
# <pre><code>print(boys)</pre></code>
# <pre><code>print(girls)</pre></code>
#
# <h3>Accessing List Elements:</h3>
# <p>Congratulations! We have our lists created. </p>
# <p>Supposing now I wanted to access a specific name from the boys list. How could I approach that?</p>
# <p>In Python3, list items are called 'elements'. Elements reside at specific 'indices' on lists.</p>
# <p>Take our boys list for example:</p>
#
# <pre><code>['Bob', 'Phil', 'Jack', 'Peter']</pre></code>
#
# <p>As we can see, there are 4 names in the list. Bob, Phil, Jack, and Peter. In Python3 we would say, there are 4 elements in the boys list</p>
# <p>Lists, as well as several other data types in Python3 are, what we call, 'zero indexed'. Meaning, simply that they begin with zero.</p>
# <p>Knowing that, we can now say that Bob resides at index 0 in the list. Peter would reside at index 3.</p>
# <p>So, to be clear. In our boys list, we can also say we have</p><span><code>[0], [1], [2], and [3]</span></code> To the computer, thats the same as calling the names Bob, Phil, Jack, and Peter.</p>
#
# <p>The proper syntax to access Jack from the list would be:</p>
# <pre><code>boys[2]</pre></code>
#
# <h3>Using Slice:</h3>
# <p>The slice method in Python3 is a powerful way to extract portions of sequences such as lists, tuples, or strings. It allows you to select a subset of elements from a collection without modifying the original data.</p>
# <p>Syntax:</p>
# <pre><code>sequence[start:end:step]</pre></code>
# <p>Where:</p>
# <ul>
#     <li><span><code>start</code></span>:The starting index(optional,default is 0)</li>
#     <li><span><code>end</code></span>:The ending index(optional, default is the length of the sequence)</li>
#     <li><span><code>step</code></span>:The increment between elements (optional, default is 1)</li>
# </ul>
# <h3>Example 1: Basic Slicing</h3>
# <pre><code>boys = ['Bob', 'Phil', 'Jack', 'Peter]</pre></code>
# <p><span><code>print(boys[1:])</code></span> # Output ['Phil, 'Jack', 'Peter']</p>
# <p><span><code>print(boys[:3]</code></span> # Output ['Bob, 'Phil', 'Jack'])</p>
# <p>Explantion:</p>
# <ul>
#     <li><span><code>boys[1:]</code></span> starts from index 1 and goes to the end</li>
#     <li><span><code>boys[:3]</code></span> starts from the beginning up to index 3 (exclusive)</li>
# </ul>
#
# <h3>Example 2: Specifying Start to End</h3>
# <p><span><code>print(boys[1:3])</code></span> # Output: ['Phil', 'Jack']</p>
# <p><span><code>print(boys[1:4:2])</code></span> # Output: ['Phil', 'Peter']</p>
# <p>Explanation:
# <ul>
#     <li><span><code>boys[1:3]</code></span> selects elements from index 1 to 3 (exclusive)</li>
#     <li><span><code>boys[1:4:2]</code></span> selects every second element starting from index 1</li>
# </ul>
#
# <h3>Example 3: Negative Indexing</h3>
# <p><span><code>print(boys[-2:]</code></span> # Output: ['Jack', 'Peter'])</p>
# <p><span><code>print(boys[:-1])</code></span> # Output ['Bob', 'Phil', 'Jack']</p>
#
# <p>Explanation:</p>
# <ul>
#     <li><span><code>boys[-2:]</code></span>selects the last two elements</li>
#     <li><span><code>boys[:-1]</code></span>selects all elements except the last one</li>
# </ul>
#
# <h3>Key Points to Remember</h3>
# <ol>
#     <li>Omitting the start index means the slice starts from the beginning of the sequence.</li>
#     <li>Omitting the end index means the slice goes to the end of the sequence.</li>
#     <li>A negative step value reverses the order of the selected elements.</li>
#     <li>The slice method returns a new list; it doesn't modify the original sequence.</li>
#     <li>Both<span><code>start</span></code>and<span><code>end</code></span>are exclusive. This means the slice includes all elements up to but not including the<span><code>end</code></span>index</li>
# </ol>
#
# <p>Ok, we have more information about lists. Perhaps now we can look further into solving our problem set. We need a Python3 program that will greet each boy and girl pair from the the list we just created.</p>
# <p>From what we have seen so far in this 3torial. There is a print function in Python3 that allows us to print things to the console</p>
#
# <h3>Print Function:</h3>
# <p>The<span><code>print</code></span>function in Python is used to output text or values to the console or standard output stream. It's one of the most commonly used functions in Python for displaying information to the user or for debugging purposes.</p>
#
# <p>Syntax:</p>
# <pre><code>print('statement')</pre></code>
#
# <p>Let's try using what we have learned to print the first name from boys list and the girls list.</p>
# <p><span><code>print(boys[0])</code></span> # Output Bob</p>
# <p><span><code>print(girls[0])</code></span> # Output Janet</p>
#
# <p>Now see if you can add 'Hello' and the name from the list</p>
# <p><span><code>print(f'Hello, {boys[0]'})</code></span> # Output Hello, Bob</p>
# <p><span><code>print(f'Hello, {girls[0]'})</code></span> # Output Hello, Janet</p>
#
# <p>Great! We are moving right along nicely.</p>
# <p>Before we can attempt to put this all together, I'd like to introduce two more concepts that work well when dealing with lists in Python3.</p>
#
# <h3>The len() Function:</h3>
# <p>The<span><code>len()</code></span>function in Python returns the number of items in an object. For lists, it returns the total count of elements.</p>
#
# <p>Syntax</p>
# <pre><code>len(list_name)</code></pre>
#
# <h3>Basic usage</h3>
# <p>The simplest use of<span><code>len</code></span>is to get the number of elements in a list:</p>
#
# <pre><code>books = ['Python', 'Sql', 'java']</pre></code>
# <pre><code>number_of_books = len(books)</pre></code>
# <p><pre><code>print(number_of_books)</pre</code> #  Output: 3</p>
#
# <h3>Using range():</h3>
# <p>The<span><code>range</code></span>function in Python3 generates a sequence of integers. It's commonly used in loops to iterate over a series of numbers, especially when working with lists or other sequences.</p>
# <p>Its syntax and fuctionality is quite similar to slicing.</p>
#
# <p>Syntax:</p>
# <pre><code>range([start], stop[, step])</pre></span>
#
# <p>Where:</p>
# <ul>
#     <li><span><code>start</code></span>: Starting number(optional, default is 0)</li>
#     <li><span><code>stop</code></span>: Ending number (exclusive)</li>
#     <li><span><code>step</code></span>: Difference between each number (optional, default is 1)</li>
# </ul>
#
# <p>In order for us to have a better understanding of how we would implement<span><code>len()</code></span>, and <span><code>range</code></span>for our problem set, it's only fair that we have a general overview of a concept in Python3 known as 'looping'</p>
# <p>There are several ways Python3 handles looping. We will focus on the 'for loop'</p>
#
# <h3>For Loops in Python3</h3>
# <p>A 'for loop' in Python is a control flow statement that allows you to execute a block of code repeatedly for a specified number of times. It's one of the most common and versatile ways to perform repetitive tasks in Python.</p>
#
# <p>Syntax:</p>
# <pre><code>for variable in iterable:</pre></code>
#     <p>#   code to be executed</p>
#
# <p>Where:</p>
# <ul>
#     <li><span><code>variable</code></span>is the temporary variable that takes on the value of each item in the iterable</li>
#     <li><span><code>iterable</code></span>is any sequence (like a list, tuple, or string) or other iterable object</li>
# </ul>
#
# <h3>Basic Usage with range()</h3>
# <pre><code>for i in range(3):</pre></code>
# <p>      # print(i)</p>
# <p>Output:</p>
# <pre><code>0</pre></code>
# <pre><code>1</pre></code>
# <pre><code>2</pre></code>
#
# <h3>Iterating Over a List:</h3>
# <pre><span>drinks = ['cheerwine', 'coke', 'pepsi']</pre></code>
# <pre><code>for drink in drinks:</pre></code>
# <p>            #print(drink)</p>
#
# <p>Output:</p>
# <pre><code>cheerwine</pre></code>
# <pre><code>coke</pre></code>
# <pre><code>pepsi</pre></code>
#
# <p>This outputs each drink in our list</p>
#
# <h3>Combining len() and range()</h3>
#
#     for person2 in group2:
#         print(f"Hello {person1} and {person2}!")
# </code></pre>
# <p><strong>Output:</strong></p>
# <pre><code>
# Hello Alice and Charlie!
# Hello Alice and David!
# Hello Bob and Charlie!
# Hello Bob and David!
# </code></pre>
#
# <h2>2. Modified Approach Using a Single Loop with Indices</h2>
# <p>In this approach, we use the <code>range()</code> and <code>len()</code> functions to iterate through the lists based on their indices. This ensures that we greet corresponding members from both lists.</p>
# <pre><code>
# # Modified approach using a single loop with indices
# group1 = ["Alice", "Bob"]
# group2 = ["Charlie", "David"]
#
# for i in range(len(group1)):
#     print(f"Hello {group1[i]} and {group2[i]}!")
# </code></pre>
# <p><strong>Output:</strong></p>
# <pre><code>
# Hello Alice and Charlie!
# Hello Bob and David!
# </code></pre>
#
# <h2>3. Alternative Approach Using the zip() Function</h2>
# <p>The <code>zip()</code> function allows us to iterate over both lists simultaneously, creating pairs of names to greet.</p>
# <pre><code>
# # Alternative approach using zip()
# group1 = ["Alice", "Bob"]
# group2 = ["Charlie", "David"]
#
# for person1, person2 in zip(group1, group2):
#     print(f"Hello {person1} and {person2}!")
# </code></pre>
# <p><strong>Output:</strong></p>
# <pre><code>
# Hello Alice and Charlie!
# Hello Bob and David!
# </code></pre>
#
# <h2>4. Handling Lists of Different Lengths</h2>
# <p>To handle cases where the lists may have different lengths, we can create a custom function that greets all members, ensuring that no one is left out.</p>
# <pre><code>
# # Handling lists of different lengths
# def greet_groups(group1, group2):
#     max_length = max(len(group1), len(group2))
#
#     for i in range(max_length):
#         person1 = group1[i] if i < len(group1) else "No one from group 1"
#         person2 = group2[i] if i < len(group2) else "No one from group 2"
#         print(f"Hello {person1} and {person2}!")
#
# group1 = ["Alice", "Bob"]
# group2 = ["Charlie", "David", "Eve"]
#
# greet_groups(group1, group2)
# </code></pre>
# <p><strong>Output:</strong></p>
# <pre><code>
# Hello Alice and Charlie!
# Hello Bob and David!
# Hello No one from group 1 and Eve!
# </code></pre>
#
# <h2>Key Points Covered</h2>
# <ul>
#     <li><strong>Basic Python Functionality</strong>: We explored loops, list indexing, and the <code>zip()</code> function.</li>
#     <li><strong>Relationships Between Lists</strong>: We demonstrated how to work with multiple lists and their relationships.</li>
#     <li><strong>Handling Different Lengths</strong>: We created a custom function to ensure all members are greeted, regardless of list length.</li>
# </ul>
#
# <p>For more Python tutorials, you can follow the provided GitHub link: <a href="https://github.com/worldfamous718/Python-Labs.git">Python Labs</a>.</p>

# %%
# World..redacted
# PAIthon Practice Labs
# Lab(Greeting.py)
# 3torials series

# Do not change the list for this exercise:
boys = ['Bob', 'Phil', 'Jack', 'Peter']
girls = ['Janet', 'Theresa', 'Jeannette', 'Lara']

# Create program to greet boys and girls:
# Initial approach. Returns undesirable results:

for boy in boys:
    for girl in girls:
         print(f'Hello, {boy}, {girl}')
        
        
# TO DO:
# Run the code to see undesirable output
# Fix code so that the output is as follows:
# Hello Bob, and Janet
# Hello Phil, and  Theresa
# Hello Jack, and Jeannette
# Hello Peter, and Lara
# Out:
# Hello, Bob, Janet
# Hello, Bob, Theresa
# Hello, Bob, Jeannette
# Hello, Bob, Lara
# Hello, Phil, Janet
# Hello, Phil, Theresa
# Hello, Phil, Jeannette
# Hello, Phil, Lara
# Hello, Jack, Janet
# Hello, Jack, Theresa
# Hello, Jack, Jeannette
# Hello, Jack, Lara
# Hello, Peter, Janet
# Hello, Peter, Theresa
# Hello, Peter, Jeannette
# Hello, Peter, Lara

# %%
# Modified approach:

# Keep note that lists in Python3 are zero-indexed:
print(boys[0])
print(girls[0]) # This prints the 0th element of each list to the terminal
# Try printing out the 3rd name in each list

# the len() function allows us to determine how many elements are in a list:
print(len(boys))
print(len(girls))

# The range() function in Python3 can be used to iterate over a list. 
# It is usually implemented in conjusction with a loop as we will use here.

for i in range(len(boys)):
    print(f'Hello {boys[i]}, and {girls[i]}')

# Let's break down why this works:
# 
# We're using range(len(boys)) in conjunction with a for loop creating an iterator for each index of the boys list.
# By accessing boys[i], we get the current boy's name at each iteration.
# Similarly, girls[i] gives us the corresponding girl's name.
# We use f strings to format the output. Including both names, separated by "and".
#
# Out:
# Bob
# Janet
# 4
# 4
# Hello Bob, and Janet
# Hello Phil, and Theresa
# Hello Jack, and Jeannette
# Hello Peter, and Lara

# %%
# Alternative approach:
# If you prefer a more Pythonic way without explicitly using indices, you could use the zip() function:
# See above for explanation

for boy, girl in zip(boys, girls):
    print(f'Hello {boy}, and {girl}')

# This approach uses the zip() function to pair up elements from the boys and girls lists. It's more concise and often preferred in Python3 for its readability.
#
# Both approaches will produce the desired output. Choose the one that best fits your coding style and preferences!
# Out:
# Hello Bob, and Janet
# Hello Phil, and Theresa
# Hello Jack, and Jeannette
# Hello Peter, and Lara

# %%
#
# Handling lists of different lengths:
# When the lists have different lengths, we need to ensure our program doesn't raise an error or produce unexpected results
# Here's how we can modify our approach to handle situations where the lists may have different lengths:

# In Python3, we use functions to define tasks that we may want to use later in our program:

# The min() and len() functions can be used together to find the shorter of two lists.
def greet_boys_and_girls(boys, girls):
    min_length = min(len(boys), len(girls))  # We can implement that functionality here
    
    for i in range(min_length):
                     print(f'Hello {boys[i]}, and {girls[i]}')
    
    # Print remaining boys (if any)
    for boy in boys[min_length:]:
                     print(f'Hello {boy}')
                     
    # Print remaining girls (if any)
    for girl in girls[min_length:]:
                     print(f'And {girl}')

# Example usage
boys = ['Bob', 'Phil', 'Jack', 'Peter', 'Mike']
girls = ['Janet', 'Theresa', 'Jeannette', 'Lara']
# 
greet_boys_and_girls(boys, girls)

# Let's break down the changes:
# 
# We calculate the minimum length between the two lists using min(len(boys), len(girls)). 
# This ensures we don't try to access elements beyond the shorter list's length.

# We iterate only up to the min_length, pairing up boys and girls as before.
# After the loop, we print any remaining boys (those after the min_length) without a corresponding girl.
# Finally, we print any remaining girls (also those after the min_length) without a corresponding boy.

# Explanation
# This approach handles several scenarios:
# 
# When the lists have the same length, it behaves exactly as before.
# When the boys' list is longer, it prints all boys paired with their corresponding girls, then prints the remaining boys.
# When the girls' list is longer, it prints all pairs, then prints the remaining girls.


# end
# Out:
# Hello Bob, and Janet
# Hello Phil, and Theresa
# Hello Jack, and Jeannette
# Hello Peter, and Lara
# Hello Mike
